# %%
import autogen

# %%
config_list = [
    
        {
        "model": "gemini-pro",
        "api_key": "AIzaSyCvDhMJK9JCVev9GSrgOSh-_GgwEqzOExU",
        "api_type": "google"
    }
    
]

# %%
task = """Write a concise but engaging blogpost about Meta."""

# %%
llm_config = {
    "config_list": config_list,
    "output_dir": "output",
    "output_file": "gemini-pro",
    "output_format": "json",
    "timeout":120
}

# %%
writer = autogen.AssistantAgent(
    name="Writer",
    llm_config=llm_config,
    system_message= """
    You are a professional writer, known for your insightful and engaging articles.
    You transform complex concepts into compelling narratives.
    You should improve the quality of the content based on the feedback from the user.
    """
)

# %%
user_proxy = autogen.UserProxyAgent(
    name="User",
    human_input_mode="NEVER",
    is_termination_msg=lambda x: x.get("content", "").find("TERMINATE") >= 0,
    code_execution_config={
        "last_n_messages": 1,
        "work_dir": "my_code",
        "use_docker": False,
    }
)

# %%
critic = autogen.AssistantAgent(
    name="Critic",
    llm_config={"config_list": config_list},
    system_message="""
    You are a critic, known for your thoroughness and commitment to standards.
    Your task is to scrutinize content for any harmful elements or regulatory violations, ensuring
    all materials align with required guidelines.
    For code
    """,
)

# %%
def reflection_message(recipient, messages, sender, config):
    print("Reflecting...")
    return f"Reflect and provide critique on the following writing. \n\n {recipient.chat_messages_for_summary(sender)[-1]['content']}"


user_proxy.register_nested_chats(
    [
        {
            "recipient": critic,
            "message": reflection_message,
            "summary_method": "last_msg",
            "max_turns": 1
         }
    ],
    trigger=writer
)

# %%
user_proxy.initiate_chat(recipient=writer,message=task,max_turns=2,summary_method="last_msg")
# Out:
# User (to Writer):
#
# Write a concise but engaging blogpost about Meta.
#
# --------------------------------------------------------------------------------
# Writer (to User):
#
# **Meta: A New Era in Social Connectivity**
#
# Meta, the parent company of Facebook, Instagram, and WhatsApp, has emerged as a juggernaut in the realm of social media. With a user base eclipsing 3 billion people, Meta is shaping the way we communicate, consume information, and connect with the world.
#
# **Unifying the Social Experience**
#
# Meta's vision is to create a "metaverse," a virtual world where users can interact with each other and with digital content in a way that mirrors real-life experiences. By integrating its platforms, Meta aims to provide a seamless and immersive social experience that transcends the boundaries of individual apps.
#
# **Driving Innovation in VR and AR**
#
# Meta is investing heavily in virtual reality (VR) and augmented reality (AR) technologies. With the Oculus Quest 2 headset, users can enter virtual worlds and interact with others in an immersive way. AR glasses, currently in development, promise to overlay digital information onto the real world, enhancing our perception and interactions with the environment.
#
# **Connecting People Globally**
#
# Meta's vast user base makes it an unparalleled platform for connecting people across borders and cultures. WhatsApp, with its end-to-end encryption, has become a lifeline for billions worldwide. Meta is also exploring new ways to use AI and machine learning to break down language barriers and foster global understanding.
#
# **Navigating Privacy Concerns**
#
# Meta's immense user data has raised concerns about privacy. The company has faced scrutiny for its data collection practices and has implemented measures to enhance user control over their information. Meta emphasizes the importance of transparency and user autonomy, while striving to balance privacy with the need for personalization and innovation.
#
# **Looking to the Future**
#
# As Meta continues to evolve, it is poised to shape the future of social media and technology. By embracing VR, AR, and AI, Meta is creating a new paradigm for human interaction and information consumption. With its commitment to innovation and global connectivity, Meta is positioned to drive the next wave of technological and social transformation.
#
# --------------------------------------------------------------------------------
# Reflecting...
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# User (to Critic):
#
# Reflect and provide critique on the following writing.
#
#  **Meta: A New Era in Social Connectivity**
#
# Meta, the parent company of Facebook, Instagram, and WhatsApp, has emerged as a juggernaut in the realm of social media. With a user base eclipsing 3 billion people, Meta is shaping the way we communicate, consume information, and connect with the world.
#
# **Unifying the Social Experience**
#
# Meta's vision is to create a "metaverse," a virtual world where users can interact with each other and with digital content in a way that mirrors real-life experiences. By integrating its platforms, Meta aims to provide a seamless and immersive social experience that transcends the boundaries of individual apps.
#
# **Driving Innovation in VR and AR**
#
# Meta is investing heavily in virtual reality (VR) and augmented reality (AR) technologies. With the Oculus Quest 2 headset, users can enter virtual worlds and interact with others in an immersive way. AR glasses, currently in development, promise to overlay digital information onto the real world, enhancing our perception and interactions with the environment.
#
# **Connecting People Globally**
#
# Meta's vast user base makes it an unparalleled platform for connecting people across borders and cultures. WhatsApp, with its end-to-end encryption, has become a lifeline for billions worldwide. Meta is also exploring new ways to use AI and machine learning to break down language barriers and foster global understanding.
#
# **Navigating Privacy Concerns**
#
# Meta's immense user data has raised concerns about privacy. The company has faced scrutiny for its data collection practices and has implemented measures to enhance user control over their information. Meta emphasizes the importance of transparency and user autonomy, while striving to balance privacy with the need for personalization and innovation.
#
# **Looking to the Future**
#
# As Meta continues to evolve, it is poised to shape the future of social media and technology. By embracing VR, AR, and AI, Meta is creating a new paradigm for human interaction and information consumption. With its commitment to innovation and global connectivity, Meta is positioned to drive the next wave of technological and social transformation.
#
# --------------------------------------------------------------------------------
# Critic (to User):
#
# **Critique**
#
# **Positive Aspects:**
#
# * The writing effectively conveys Meta's role and impact in the social media landscape, particularly its vision for the metaverse and investment in VR/AR technologies.
# * It highlights Meta's global reach and its potential to connect people across borders and cultures.
# * The writing acknowledges the privacy concerns associated with Meta's data collection practices, emphasizing the company's efforts to enhance user control and transparency.
#
# **Areas for Improvement:**
#
# **Lack of Critical Evaluation:**
#
# * While the writing provides a general overview of Meta's activities, it lacks a critical evaluation of the company's practices or potential negative consequences.
# * It does not address the ethical concerns raised by the metaverse, such as privacy risks, addiction potential, and social isolation.
#
# **Overemphasis on Company Perspectives:**
#
# * The writing primarily presents Meta's perspective and vision without considering alternative viewpoints or criticisms.
# * It does not explore the potential drawbacks or limitations of Meta's platforms or technologies.
#
# **Incomplete Regulatory Discussion:**
#
# * The writing briefly mentions Meta's privacy concerns but does not delve into the specific regulatory violations or potential legal issues the company has faced.
# * It should provide a more comprehensive analysis of Meta's compliance with privacy laws and industry standards.
#
# **Dense Technical Language:**
#
# * The writing includes technical terms such as "metaverse," "VR," and "AR" without adequately explaining their significance or implications for general readers.
# * It may alienate readers unfamiliar with these technologies.
#
# **Suggested Improvements:**
#
# * Incorporate critical evaluation of Meta's practices and potential negative consequences, including ethical concerns about the metaverse.
# * Present a balanced perspective by including opposing viewpoints or critiques of Meta.
# * Provide a more comprehensive analysis of Meta's regulatory compliance and its implications for privacy.
# * Explain technical terms clearly and provide context for their relevance to social connectivity.
# * Consider adding examples or case studies to illustrate Meta's impact on individuals and society.
#
# --------------------------------------------------------------------------------
# User (to Writer):
#
# **Critique**
#
# **Positive Aspects:**
#
# * The writing effectively conveys Meta's role and impact in the social media landscape, particularly its vision for the metaverse and investment in VR/AR technologies.
# * It highlights Meta's global reach and its potential to connect people across borders and cultures.
# * The writing acknowledges the privacy concerns associated with Meta's data collection practices, emphasizing the company's efforts to enhance user control and transparency.
#
# **Areas for Improvement:**
#
# **Lack of Critical Evaluation:**
#
# * While the writing provides a general overview of Meta's activities, it lacks a critical evaluation of the company's practices or potential negative consequences.
# * It does not address the ethical concerns raised by the metaverse, such as privacy risks, addiction potential, and social isolation.
#
# **Overemphasis on Company Perspectives:**
#
# * The writing primarily presents Meta's perspective and vision without considering alternative viewpoints or criticisms.
# * It does not explore the potential drawbacks or limitations of Meta's platforms or technologies.
#
# **Incomplete Regulatory Discussion:**
#
# * The writing briefly mentions Meta's privacy concerns but does not delve into the specific regulatory violations or potential legal issues the company has faced.
# * It should provide a more comprehensive analysis of Meta's compliance with privacy laws and industry standards.
#
# **Dense Technical Language:**
#
# * The writing includes technical terms such as "metaverse," "VR," and "AR" without adequately explaining their significance or implications for general readers.
# * It may alienate readers unfamiliar with these technologies.
#
# **Suggested Improvements:**
#
# * Incorporate critical evaluation of Meta's practices and potential negative consequences, including ethical concerns about the metaverse.
# * Present a balanced perspective by including opposing viewpoints or critiques of Meta.
# * Provide a more comprehensive analysis of Meta's regulatory compliance and its implications for privacy.
# * Explain technical terms clearly and provide context for their relevance to social connectivity.
# * Consider adding examples or case studies to illustrate Meta's impact on individuals and society.
#
# --------------------------------------------------------------------------------
# Writer (to User):
#
# **Improved Blog Post with Critical Evaluation**
#
# **Meta: A New Era in Social Connectivity—But at What Cost?**
#
# Meta, the parent company of Facebook, Instagram, and WhatsApp, has emerged as a juggernaut in the realm of social media. With a user base eclipsing 3 billion people, Meta is shaping the way we communicate, consume information, and connect with the world.
#
# **Unifying the Social Experience and Driving Innovation**
#
# Meta's vision for a "metaverse," a virtual world where users can interact with each other and with digital content in an immersive way, is ambitious. By integrating its platforms, Meta aims to provide a seamless and immersive social experience that transcends the boundaries of individual apps. Meta is also investing heavily in virtual reality (VR) and augmented reality (AR) technologies, pushing the boundaries of human interaction and information consumption.
#
# **Connecting People Globally**
#
# Meta's vast user base makes it an unparalleled platform for connecting people across borders and cultures. WhatsApp, with its end-to-end encryption, has become a lifeline for billions worldwide. However, concerns have been raised about the company's ability to safeguard user data and prevent the spread of misinformation.
#
# **Navigating Privacy Concerns and Regulatory Scrutiny**
#
# Meta's immense user data has raised concerns about privacy. The company has faced scrutiny for its data collection practices and has been fined billions of dollars for violating privacy laws. While Meta emphasizes transparency and user autonomy, critics argue that the company's privacy policies are complex and difficult to understand.
#
# **Ethical Concerns about the Metaverse**
#
# The metaverse, while promising immersive experiences, also raises ethical concerns. Privacy risks are paramount, as the metaverse could collect vast amounts of data about users' behavior and interactions. Addiction potential is another concern, as users may spend excessive time in virtual worlds, neglecting real-life responsibilities. Social isolation is also a potential issue, as users may retreat into the metaverse at the expense of face-to-face interactions.
#
# **Balancing Innovation with Responsibility**
#
# As Meta continues to evolve, it is imperative that the company balances innovation with social responsibility. The metaverse has the potential to revolutionize the way we connect and interact, but it is essential to address privacy concerns, mitigate addiction risks, and prevent social isolation. Meta must work closely with regulators, privacy advocates, and ethicists to ensure that the metaverse is a positive force for society.
#
# By acknowledging the challenges and ethical concerns associated with its platforms and technologies, Meta can continue to drive innovation while fostering a safe and responsible social media landscape.
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': 'Write a concise but engaging blogpost about Meta.', 'role': 'assistant', 'name': 'User'}, {'content': '**Meta: A New Era in Social Connectivity**\n\nMeta, the parent company of Facebook, Instagram, and WhatsApp, has emerged as a juggernaut in the realm of social media. With a user base eclipsing 3 billion people, Meta is shaping the way we communicate, consume information, and connect with the world.\n\n**Unifying the Social Experience**\n\nMeta\'s vision is to create a "metaverse," a virtual world where users can interact with each other and with digital content in a way that mirrors real-life experiences. By integrating its platforms, Meta aims to provide a seamless and immersive social experience that transcends the boundaries of individual apps.\n\n**Driving Innovation in VR and AR**\n\nMeta is investing heavily in virtual reality (VR) and augmented reality (AR) technologies. With the Oculus Quest 2 headset, users can enter virtual worlds and interact with others in an immersive way. AR glasses, currently in development, promise to overlay digital information onto the real world, enhancing our perception and interactions with the environment.\n\n**Connecting People Globally**\n\nMeta\'s vast user base makes it an unparalleled platform for connecting people across borders and cultures. WhatsApp, with its end-to-end encryption, has become a lifeline for billions worldwide. Meta is also exploring new ways to use AI and machine learning to break down language barriers and foster global understanding.\n\n**Navigating Privacy Concerns**\n\nMeta\'s immense user data has raised concerns about privacy. The company has faced scrutiny for its data collection practices and has implemented measures to enhance user control over their information. Meta emphasizes the importance of transparency and user autonomy, while striving to balance privacy with the need for personalization and innovation.\n\n**Looking to the Future**\n\nAs Meta continues to evolve, it is poised to shape the future of social media and technology. By embracing VR, AR, and AI, Meta is creating a new paradigm for human interaction and information consumption. With its commitment to innovation and global connectivity, Meta is positioned to drive the next wave of technological and social transformation.', 'role': 'user', 'name': 'Writer'}, {'content': '**Critique**\n\n**Positive Aspects:**\n\n* The writing effectively conveys Meta\'s role and impact in the social media landscape, particularly its vision for the metaverse and investment in VR/AR technologies.\n* It highlights Meta\'s global reach and its potential to connect people across borders and cultures.\n* The writing acknowledges the privacy concerns associated with Meta\'s data collection practices, emphasizing the company\'s efforts to enhance user control and transparency.\n\n**Areas for Improvement:**\n\n**Lack of Critical Evaluation:**\n\n* While the writing provides a general overview of Meta\'s activities, it lacks a critical evaluation of the company\'s practices or potential negative consequences.\n* It does not address the ethical concerns raised by the metaverse, such as privacy risks, addiction potential, and social isolation.\n\n**Overemphasis on Company Perspectives:**\n\n* The writing primarily presents Meta\'s perspective and vision without considering alternative viewpoints or criticisms.\n* It does not explore the potential drawbacks or limitations of Meta\'s platforms or technologies.\n\n**Incomplete Regulatory Discussion:**\n\n* The writing briefly mentions Meta\'s privacy concerns but does not delve into the specific regulatory violations or potential legal issues the company has faced.\n* It should provide a more comprehensive analysis of Meta\'s compliance with privacy laws and industry standards.\n\n**Dense Technical Language:**\n\n* The writing includes technical terms such as "metaverse," "VR," and "AR" without adequately explaining thei ...
